# %% [markdown]
# # 08 — Unified Model Comparison Chart

# %%
import sys
from pathlib import Path
ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))

import subprocess
subprocess.run([sys.executable, str(ROOT / "scripts" / "plot_model_comparison.py")], cwd=str(ROOT), check=True)

# %%
from IPython.display import display
import pandas as pd
from IPython.display import Image, display

results_dir = ROOT / "outputs" / "results"
df = pd.read_csv(results_dir / "all_models_comparison.csv")
print(f"Total models: {len(df)}")
print(df.groupby("tier")["accuracy"].agg(["count", "mean", "max"]).round(3))

display(df.head(15))

# %%
from IPython.display import display
display(Image(filename=str(results_dir / "all_models_comparison.png")))
display(Image(filename=str(results_dir / "fusion_strategy_comparison.png")))

print("08_model_comparison.py complete.")
